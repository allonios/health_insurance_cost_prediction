# %%
from utils.utils import import_from_json, get_best_model

# %%
models = import_from_json("dist/result_all.json")

for model in models:
    model.display()
    print("---------------------------------------------------------------------------------------------------------------")
# Out:
#  lr_ridge
#
#  Model Result:
#                    MSE  R2 Score
# 0  Train  1.821761e+07  0.837996
# 1   Test  1.823147e+07  0.862191
# Grid Search Best Params:
#                         param  values
# 0  polynomialfeatures__degree       3
# 1                ridge__alpha       5
# 2             ridge__max_iter    1000
# ---------------------------------------------------------------------------------------------------------------
#  lr_ridge_rfe
#
#  Model Result:
#                    MSE  R2 Score
# 0  Train  1.863082e+07  0.834322
# 1   Test  1.894867e+07  0.856770
# Grid Search Best Params:
#                         param  values
# 0  polynomialfeatures__degree       3
# 1                ridge__alpha      10
# 2             ridge__max_iter    1000
# ---------------------------------------------------------------------------------------------------------------
#  lr_lasso
#
#  Model Result:
#                    MSE  R2 Score
# 0  Train  1.889382e+07  0.831983
# ...
